# %% [markdown]
# # Complete  Pandas

# %%
# pip install pandas ------to install pandas
import pandas as pd

# %%
d = pd.read_excel("C:\\Users\\tejas\\OneDrive\\Desktop\\Marks.xlsx") # reading the file

# %% [markdown]
# ### Creating the DataFrame

# %%
df = pd.DataFrame(d) # converting the data into the table

d
# Out:
#     Roll No Name_of_Student  Telugu  English  Maths  Science  Social
# 0         1          Olivia      99       99     99       99      99
# 1         2            Emma      67       67     67       67      67
# 2         3       Charlotte      76       76     76       76      76
# 3         4          Amelia      34       34     34       34      34
# 4         5             Ava      89       89     89       89      89
# 5         6          Sophia      43       43     43       43      43
# 6         7        Isabella      69       69     69       69      69
# 7         8             Mia      90       90     90       90      90
# 8         9          Evelyn      34       34     34       34      34
# 9        10          Harper      76       76     76       76      76
# 10       11            Luna      65       65     65       65      65
# 11       12          Camila      32       32     32       32      32
# 12       13          Gianna      78       78     78       78      78
# ...

# %% [markdown]
# ## Indexing and Slicing

# %%
# this command give you top five rows or we can give the range also ------->DataFrame.head()
df.head()
# Out:
#    Roll No Name_of_Student  Telugu  English  Maths  Science  Social
# 0        1          Olivia      99       99     99       99      99
# 1        2            Emma      67       67     67       67      67
# 2        3       Charlotte      76       76     76       76      76
# 3        4          Amelia      34       34     34       34      34
# 4        5             Ava      89       89     89       89      89

# %%
df.head(7)
# Out:
#    Roll No Name_of_Student  Telugu  English  Maths  Science  Social
# 0        1          Olivia      99       99     99       99      99
# 1        2            Emma      67       67     67       67      67
# 2        3       Charlotte      76       76     76       76      76
# 3        4          Amelia      34       34     34       34      34
# 4        5             Ava      89       89     89       89      89
# 5        6          Sophia      43       43     43       43      43
# 6        7        Isabella      69       69     69       69      69

# %%
# similarly we can access the data from the bottom also---->DataFrame.tail()
df.tail()
# Out:
#     Roll No Name_of_Student  Telugu  English  Maths  Science  Social
# 15       16            Ella      56       56     56       56      56
# 16       17         Abigail      34       34     34       34      34
# 17       18            Liam      78       78     78       78      78
# 18       19            Noah      89       89     89       89      89
# 19       20          Oliver      98       98     98       98      98

# %%
df.tail(7)
# Out:
#     Roll No Name_of_Student  Telugu  English  Maths  Science  Social
# 13       14       Elizabeth      89       89     89       89      89
# 14       15         Eleanor      89       89     89       89      89
# 15       16            Ella      56       56     56       56      56
# 16       17         Abigail      34       34     34       34      34
# 17       18            Liam      78       78     78       78      78
# 18       19            Noah      89       89     89       89      89
# 19       20          Oliver      98       98     98       98      98

# %%
# This command will caluculate the count,mean,median,std,min,max----DataFrame.describe()
df.describe()
# Out:
#         Roll No    Telugu   English     Maths   Science    Social
# count  20.00000  20.00000  20.00000  20.00000  20.00000  20.00000
# mean   10.50000  69.25000  69.25000  69.25000  69.25000  69.25000
# std     5.91608  22.88386  22.88386  22.88386  22.88386  22.88386
# min     1.00000  32.00000  32.00000  32.00000  32.00000  32.00000
# 25%     5.75000  52.75000  52.75000  52.75000  52.75000  52.75000
# 50%    10.50000  76.00000  76.00000  76.00000  76.00000  76.00000
# 75%    15.25000  89.00000  89.00000  89.00000  89.00000  89.00000
# max    20.00000  99.00000  99.00000  99.00000  99.00000  99.00000

# %%
# This command will give the shape of the data------>DataFrame(Count of rows, count of the colums)
df.shape
# Out:
# (20, 7)

# %%
# DataFrame[Start:Stop:step]
df[0:10:1] # example-1 # Start is inclusive and Stop is Exclusive
# Out:
#    Roll No Name_of_Student  Telugu  English  Maths  Science  Social
# 0        1          Olivia      99       99     99       99      99
# 1        2            Emma      67       67     67       67      67
# 2        3       Charlotte      76       76     76       76      76
# 3        4          Amelia      34       34     34       34      34
# 4        5             Ava      89       89     89       89      89
# 5        6          Sophia      43       43     43       43      43
# 6        7        Isabella      69       69     69       69      69
# 7        8             Mia      90       90     90       90      90
# 8        9          Evelyn      34       34     34       34      34
# 9       10          Harper      76       76     76       76      76

# %%
# example-2
df[0:10:2]
# Out:
#    Roll No Name_of_Student  Telugu  English  Maths  Science  Social
# 0        1          Olivia      99       99     99       99      99
# 2        3       Charlotte      76       76     76       76      76
# 4        5             Ava      89       89     89       89      89
# 6        7        Isabella      69       69     69       69      69
# 8        9          Evelyn      34       34     34       34      34

# %%
# df["column name"] this command is used to access the particular column.

df["Name_of_Student"] # here column name is case sensitive
# Out:
# 0        Olivia
# 1          Emma
# 2     Charlotte
# 3        Amelia
# 4           Ava
# 5        Sophia
# 6      Isabella
# 7           Mia
# 8        Evelyn
# 9        Harper
# 10         Luna
# 11       Camila
# 12       Gianna
# 13    Elizabeth
# 14      Eleanor
# 15         Ella
# 16      Abigail
# 17         Liam
# 18         Noah
# 19       Oliver
# Name: Name_of_Student, dtype: object

# %%
df[["Name_of_Student","English"]] # we can also access the mutiple columns at a time
# Out:
#    Name_of_Student  English
# 0           Olivia       99
# 1             Emma       67
# 2        Charlotte       76
# 3           Amelia       34
# 4              Ava       89
# 5           Sophia       43
# 6         Isabella       69
# 7              Mia       90
# 8           Evelyn       34
# 9           Harper       76
# 10            Luna       65
# 11          Camila       32
# 12          Gianna       78
# 13       Elizabeth       89
# 14         Eleanor       89
# 15            Ella       56
# 16         Abigail       34
# 17            Liam       78
# 18            Noah       89
# 19          Oliver       98

# %%
# df[["column_1","column_2"]][Start:Stop:Step] 

df[["Name_of_Student","Telugu"]][2:8:1] # Start is inclusive and Stop is Exclusive
# Out:
#   Name_of_Student  Telugu
# 2       Charlotte      76
# 3          Amelia      34
# 4             Ava      89
# 5          Sophia      43
# 6        Isabella      69
# 7             Mia      90

# %%
# This commmand will show the data in tuple format
for rec in df.iterrows():
    print(rec)
# Out:
# (0, Roll No                 1
# Name_of_Student    Olivia
# Telugu                 99
# English                99
# Maths                  99
# Science                99
# Social                 99
# Name: 0, dtype: object)
# (1, Roll No               2
# Name_of_Student    Emma
# Telugu               67
# English              67
# Maths                67
# Science              67
# Social               67
# Name: 1, dtype: object)
# (2, Roll No                    3
# Name_of_Student    Charlotte
# Telugu                    76
# English                   76
# Maths                     76
# Science                   76
# Social                    76
# Name: 2, dtype: object)
# (3, Roll No                 4
# Name_of_Student    Amelia
# Telugu                 34
# English                34
# Maths                  34
# Science                34
# Social                 34
# Name: 3, dtype: object)
# (4, Roll No              5
# Name_of_Student    Ava
# Telugu              89
# ...

# %% [markdown]
# # UnderStanding-----------LOC------------here start and stop are included

# %%
# df.loc[row number]
df.loc[4] # this will give the single row in tuple format
# Out:
# Roll No              5
# Name_of_Student    Ava
# Telugu              89
# English             89
# Maths               89
# Science             89
# Social              89
# Name: 4, dtype: object

# %%
# By this command we can get data from particular row and column
df.loc[4,["Name_of_Student"]]
# Out:
# Name_of_Student    Ava
# Name: 4, dtype: object

# %%
df.loc[1:10]
# Out:
#     Roll No Name_of_Student  Telugu  English  Maths  Science  Social
# 1         2            Emma      67       67     67       67      67
# 2         3       Charlotte      76       76     76       76      76
# 3         4          Amelia      34       34     34       34      34
# 4         5             Ava      89       89     89       89      89
# 5         6          Sophia      43       43     43       43      43
# 6         7        Isabella      69       69     69       69      69
# 7         8             Mia      90       90     90       90      90
# 8         9          Evelyn      34       34     34       34      34
# 9        10          Harper      76       76     76       76      76
# 10       11            Luna      65       65     65       65      65

# %%
df.loc[0:10,["Name_of_Student"]] # Stop index is exclusive
# Out:
#    Name_of_Student
# 0           Olivia
# 1             Emma
# 2        Charlotte
# 3           Amelia
# 4              Ava
# 5           Sophia
# 6         Isabella
# 7              Mia
# 8           Evelyn
# 9           Harper
# 10            Luna

# %%
df.loc[0:10,["Name_of_Student","Telugu","English"]]
# Out:
#    Name_of_Student  Telugu  English
# 0           Olivia      99       99
# 1             Emma      67       67
# 2        Charlotte      76       76
# 3           Amelia      34       34
# 4              Ava      89       89
# 5           Sophia      43       43
# 6         Isabella      69       69
# 7              Mia      90       90
# 8           Evelyn      34       34
# 9           Harper      76       76
# 10            Luna      65       65

# %%
df.loc[0:10,"Name_of_Student":"Maths"] # Column range
# Out:
#    Name_of_Student  Telugu  English  Maths
# 0           Olivia      99       99     99
# 1             Emma      67       67     67
# 2        Charlotte      76       76     76
# 3           Amelia      34       34     34
# 4              Ava      89       89     89
# 5           Sophia      43       43     43
# 6         Isabella      69       69     69
# 7              Mia      90       90     90
# 8           Evelyn      34       34     34
# 9           Harper      76       76     76
# 10            Luna      65       65     65

# %% [markdown]
# # UnderStanding----------ILOC---------here start included and stop are excluded

# %%
# df.iloc[row numder,column numder]
df.iloc[6,1]
# Out:
# 'Isabella'

# %%
# df.iloc[row_Start:row_Stop,Column_start:Column_stop]
df.iloc[0:8,0:5]
# Out:
#    Roll No Name_of_Student  Telugu  English  Maths
# 0        1          Olivia      99       99     99
# 1        2            Emma      67       67     67
# 2        3       Charlotte      76       76     76
# 3        4          Amelia      34       34     34
# 4        5             Ava      89       89     89
# 5        6          Sophia      43       43     43
# 6        7        Isabella      69       69     69
# 7        8             Mia      90       90     90

# %%
# df.iloc[start:stop,"column number"]
df.iloc[0:10,1]
# Out:
# 0       Olivia
# 1         Emma
# 2    Charlotte
# 3       Amelia
# 4          Ava
# 5       Sophia
# 6     Isabella
# 7          Mia
# 8       Evelyn
# 9       Harper
# Name: Name_of_Student, dtype: object

# %%
# df.iloc[[row1, row2, row3]]
df.iloc[[1,3,4,6,7]]
# Out:
#    Roll No Name_of_Student  Telugu  English  Maths  Science  Social
# 1        2            Emma      67       67     67       67      67
# 3        4          Amelia      34       34     34       34      34
# 4        5             Ava      89       89     89       89      89
# 6        7        Isabella      69       69     69       69      69
# 7        8             Mia      90       90     90       90      90

# %%
# df.iloc[:,[column-1 number,column-2 number]]
df.iloc[:,[1,2,3,4]]
# Out:
#    Name_of_Student  Telugu  English  Maths
# 0           Olivia      99       99     99
# 1             Emma      67       67     67
# 2        Charlotte      76       76     76
# 3           Amelia      34       34     34
# 4              Ava      89       89     89
# 5           Sophia      43       43     43
# 6         Isabella      69       69     69
# 7              Mia      90       90     90
# 8           Evelyn      34       34     34
# 9           Harper      76       76     76
# 10            Luna      65       65     65
# 11          Camila      32       32     32
# 12          Gianna      78       78     78
# 13       Elizabeth      89       89     89
# 14         Eleanor      89       89     89
# 15            Ella      56       56     56
# 16         Abigail      34       34     34
# 17            Liam      78       78     78
# 18            Noah      89       89     89
# 19          Oliver      98       98     98

# %%
# df.iloc[Start:Stop,[column-1 number,column-2 number]]
df.iloc[0:6,[1,2,3,4]]
# Out:
#   Name_of_Student  Telugu  English  Maths
# 0          Olivia      99       99     99
# 1            Emma      67       67     67
# 2       Charlotte      76       76     76
# 3          Amelia      34       34     34
# 4             Ava      89       89     89
# 5          Sophia      43       43     43

# %% [markdown]
# # Sorting Data Frame

# %%
# dataframe.sort_values("column_name") --This will arrange the data in ascending order
df.sort_values("Name_of_Student")
# Out:
#     Roll No Name_of_Student  Telugu  English  Maths  Science  Social
# 16       17         Abigail      34       34     34       34      34
# 3         4          Amelia      34       34     34       34      34
# 4         5             Ava      89       89     89       89      89
# 11       12          Camila      32       32     32       32      32
# 2         3       Charlotte      76       76     76       76      76
# 14       15         Eleanor      89       89     89       89      89
# 13       14       Elizabeth      89       89     89       89      89
# 15       16            Ella      56       56     56       56      56
# 1         2            Emma      67       67     67       67      67
# 8         9          Evelyn      34       34     34       34      34
# 12       13          Gianna      78       78     78       78      78
# 9        10          Harper      76       76     76       76      76
# 6         7        Isabella      69       69     69       69      69
# ...

# %%
# df.sort_values("column_name",ascending= False) This will arrange the data in decending order 
df.sort_values("Name_of_Student",ascending= False)
# Out:
#     Roll No Name_of_Student  Telugu  English  Maths  Science  Social
# 5         6          Sophia      43       43     43       43      43
# 0         1          Olivia      99       99     99       99      99
# 19       20          Oliver      98       98     98       98      98
# 18       19            Noah      89       89     89       89      89
# 7         8             Mia      90       90     90       90      90
# 10       11            Luna      65       65     65       65      65
# 17       18            Liam      78       78     78       78      78
# 6         7        Isabella      69       69     69       69      69
# 9        10          Harper      76       76     76       76      76
# 12       13          Gianna      78       78     78       78      78
# 8         9          Evelyn      34       34     34       34      34
# 1         2            Emma      67       67     67       67      67
# 15       16            Ella      56       56     56       56      56
# ...

# %%
# df.sort_values(["Column_name_1","Column_name_2"])

df.sort_values(["Name_of_Student","English"])
# Out:
#     Roll No Name_of_Student  Telugu  English  Maths  Science  Social
# 16       17         Abigail      34       34     34       34      34
# 3         4          Amelia      34       34     34       34      34
# 4         5             Ava      89       89     89       89      89
# 11       12          Camila      32       32     32       32      32
# 2         3       Charlotte      76       76     76       76      76
# 14       15         Eleanor      89       89     89       89      89
# 13       14       Elizabeth      89       89     89       89      89
# 15       16            Ella      56       56     56       56      56
# 1         2            Emma      67       67     67       67      67
# 8         9          Evelyn      34       34     34       34      34
# 12       13          Gianna      78       78     78       78      78
# 9        10          Harper      76       76     76       76      76
# 6         7        Isabella      69       69     69       69      69
# ...

# %%
# df.sort_values(["column_name_1","Column_name_2"],ascending= False)
df.sort_values(["Name_of_Student","English"],ascending= False)
# Out:
#     Roll No Name_of_Student  Telugu  English  Maths  Science  Social
# 5         6          Sophia      43       43     43       43      43
# 0         1          Olivia      99       99     99       99      99
# 19       20          Oliver      98       98     98       98      98
# 18       19            Noah      89       89     89       89      89
# 7         8             Mia      90       90     90       90      90
# 10       11            Luna      65       65     65       65      65
# 17       18            Liam      78       78     78       78      78
# 6         7        Isabella      69       69     69       69      69
# 9        10          Harper      76       76     76       76      76
# 12       13          Gianna      78       78     78       78      78
# 8         9          Evelyn      34       34     34       34      34
# 1         2            Emma      67       67     67       67      67
# 15       16            Ella      56       56     56       56      56
# ...

# %% [markdown]
# # Data Frame Manipulation

# %% [markdown]
# ### Adding the column

# %%
# dataFrame["new_column_name"]=default_value.

df["Total"]= 0 # this will create the new column with the default value which is given

# %%
df
# Out:
#     Roll No Name_of_Student  Telugu  English  Maths  Science  Social  Total
# 0         1          Olivia      99       99     99       99      99      0
# 1         2            Emma      67       67     67       67      67      0
# 2         3       Charlotte      76       76     76       76      76      0
# 3         4          Amelia      34       34     34       34      34      0
# 4         5             Ava      89       89     89       89      89      0
# 5         6          Sophia      43       43     43       43      43      0
# 6         7        Isabella      69       69     69       69      69      0
# 7         8             Mia      90       90     90       90      90      0
# 8         9          Evelyn      34       34     34       34      34      0
# 9        10          Harper      76       76     76       76      76      0
# 10       11            Luna      65       65     65       65      65      0
# ...

# %%
# dataFrame["new_column_name"]=expression/condition

df["Total"]=df["Telugu"]+df["English"]+df["Maths"]+df["Science"]+df["Social"]
df
# Out:
#     Roll No Name_of_Student  Telugu  English  Maths  Science  Social  Total
# 0         1          Olivia      99       99     99       99      99    495
# 1         2            Emma      67       67     67       67      67    335
# 2         3       Charlotte      76       76     76       76      76    380
# 3         4          Amelia      34       34     34       34      34    170
# 4         5             Ava      89       89     89       89      89    445
# 5         6          Sophia      43       43     43       43      43    215
# 6         7        Isabella      69       69     69       69      69    345
# 7         8             Mia      90       90     90       90      90    450
# 8         9          Evelyn      34       34     34       34      34    170
# 9        10          Harper      76       76     76       76      76    380
# 10       11            Luna      65       65     65       65      65    325
# ...

# %%
df["percentage"]=df["Total"]/500*100

# %%
df
# Out:
#     Roll No Name_of_Student  Telugu  English  Maths  Science  Social  Total  \
# 0         1          Olivia      99       99     99       99      99    495
# 1         2            Emma      67       67     67       67      67    335
# 2         3       Charlotte      76       76     76       76      76    380
# 3         4          Amelia      34       34     34       34      34    170
# 4         5             Ava      89       89     89       89      89    445
# 5         6          Sophia      43       43     43       43      43    215
# 6         7        Isabella      69       69     69       69      69    345
# 7         8             Mia      90       90     90       90      90    450
# 8         9          Evelyn      34       34     34       34      34    170
# 9        10          Harper      76       76     76       76      76    380
# 10       11            Luna      65       65     65       65      65    325
# ...

# %%
df["Grade"]="Pass/Fail"

# %%
df
# Out:
#     Roll No Name_of_Student  Telugu  English  Maths  Science  Social  Total  \
# 0         1          Olivia      99       99     99       99      99    495
# 1         2            Emma      67       67     67       67      67    335
# 2         3       Charlotte      76       76     76       76      76    380
# 3         4          Amelia      34       34     34       34      34    170
# 4         5             Ava      89       89     89       89      89    445
# 5         6          Sophia      43       43     43       43      43    215
# 6         7        Isabella      69       69     69       69      69    345
# 7         8             Mia      90       90     90       90      90    450
# 8         9          Evelyn      34       34     34       34      34    170
# 9        10          Harper      76       76     76       76      76    380
# 10       11            Luna      65       65     65       65      65    325
# ...

# %% [markdown]
# ### Removing the column

# %%
df.drop(columns="Grade")
# Out:
#     Roll No Name_of_Student  Telugu  English  Maths  Science  Social  Total  \
# 0         1          Olivia      99       99     99       99      99    495
# 1         2            Emma      67       67     67       67      67    335
# 2         3       Charlotte      76       76     76       76      76    380
# 3         4          Amelia      34       34     34       34      34    170
# 4         5             Ava      89       89     89       89      89    445
# 5         6          Sophia      43       43     43       43      43    215
# 6         7        Isabella      69       69     69       69      69    345
# 7         8             Mia      90       90     90       90      90    450
# 8         9          Evelyn      34       34     34       34      34    170
# 9        10          Harper      76       76     76       76      76    380
# 10       11            Luna      65       65     65       65      65    325
# ...

# %% [markdown]
# # Removing the duplicate values

# %% [markdown]
# ### Knowing the Duplicates

# %%
df = pd.read_excel("C:\\Users\\tejas\\OneDrive\\Desktop\\Marks.xlsx",sheet_name="Sheet2")
df
# Out:
#     Roll No Name_of_Student  Telugu  English  Maths  Science  Social
# 0         1          Olivia    99.0     99.0   99.0       99    99.0
# 1         2            Emma    67.0     67.0   67.0       67    67.0
# 2         3       Charlotte    76.0     76.0   76.0       76    76.0
# 3         4          Amelia    34.0     34.0   34.0       34    34.0
# 4         5             NaN    89.0     89.0   89.0       89    89.0
# 5         6          Sophia    43.0     43.0   43.0       43    43.0
# 6         7        Isabella    69.0     69.0   69.0       69    69.0
# 7         8             Mia    90.0     90.0   90.0       90    90.0
# 8         9          Evelyn    34.0     34.0    NaN       34    34.0
# 9        10          Harper    76.0     76.0   76.0       76    76.0
# 10       11            Luna    65.0     65.0   65.0       65    65.0
# 11       12          Camila    32.0      NaN   32.0       32    32.0
# 12       13          Gianna    78.0     78.0   78.0       78     NaN
# ...

# %%
# df.duplicated() # This line will find the duplicated values
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20     True
# 21     True
# dtype: bool

# %% [markdown]
# # Removing the dulicates

# %%
df.drop_duplicates() # this will remove the data temporarily
# Out:
#     Roll No Name_of_Student  Telugu  English  Maths  Science  Social
# 0         1          Olivia    99.0     99.0   99.0       99    99.0
# 1         2            Emma    67.0     67.0   67.0       67    67.0
# 2         3       Charlotte    76.0     76.0   76.0       76    76.0
# 3         4          Amelia    34.0     34.0   34.0       34    34.0
# 4         5             NaN    89.0     89.0   89.0       89    89.0
# 5         6          Sophia    43.0     43.0   43.0       43    43.0
# 6         7        Isabella    69.0     69.0   69.0       69    69.0
# 7         8             Mia    90.0     90.0   90.0       90    90.0
# 8         9          Evelyn    34.0     34.0    NaN       34    34.0
# 9        10          Harper    76.0     76.0   76.0       76    76.0
# 10       11            Luna    65.0     65.0   65.0       65    65.0
# 11       12          Camila    32.0      NaN   32.0       32    32.0
# 12       13          Gianna    78.0     78.0   78.0       78     NaN
# ...

# %%
df
# Out:
#     Roll No Name_of_Student  Telugu  English  Maths  Science  Social
# 0         1          Olivia    99.0     99.0   99.0       99    99.0
# 1         2            Emma    67.0     67.0   67.0       67    67.0
# 2         3       Charlotte    76.0     76.0   76.0       76    76.0
# 3         4          Amelia    34.0     34.0   34.0       34    34.0
# 4         5             NaN    89.0     89.0   89.0       89    89.0
# 5         6          Sophia    43.0     43.0   43.0       43    43.0
# 6         7        Isabella    69.0     69.0   69.0       69    69.0
# 7         8             Mia    90.0     90.0   90.0       90    90.0
# 8         9          Evelyn    34.0     34.0    NaN       34    34.0
# 9        10          Harper    76.0     76.0   76.0       76    76.0
# 10       11            Luna    65.0     65.0   65.0       65    65.0
# 11       12          Camila    32.0      NaN   32.0       32    32.0
# 12       13          Gianna    78.0     78.0   78.0       78     NaN
# ...

# %%
df.drop_duplicates(inplace=True) # This command will perminantly delete the data frome the table

# %%
df
# Out:
#     Roll No Name_of_Student  Telugu  English  Maths  Science  Social
# 0         1          Olivia    99.0     99.0   99.0       99    99.0
# 1         2            Emma    67.0     67.0   67.0       67    67.0
# 2         3       Charlotte    76.0     76.0   76.0       76    76.0
# 3         4          Amelia    34.0     34.0   34.0       34    34.0
# 4         5             NaN    89.0     89.0   89.0       89    89.0
# 5         6          Sophia    43.0     43.0   43.0       43    43.0
# 6         7        Isabella    69.0     69.0   69.0       69    69.0
# 7         8             Mia    90.0     90.0   90.0       90    90.0
# 8         9          Evelyn    34.0     34.0    NaN       34    34.0
# 9        10          Harper    76.0     76.0   76.0       76    76.0
# 10       11            Luna    65.0     65.0   65.0       65    65.0
# 11       12          Camila    32.0      NaN   32.0       32    32.0
# 12       13          Gianna    78.0     78.0   78.0       78     NaN
# ...

# %% [markdown]
# # Handling the Missing Data

# %% [markdown]
# ### Removing the missing

# %%
df.dropna() # this command will temporarily remove the missing data
# Out:
#     Roll No Name_of_Student  Telugu  English  Maths  Science  Social
# 0         1          Olivia    99.0     99.0   99.0       99    99.0
# 1         2            Emma    67.0     67.0   67.0       67    67.0
# 2         3       Charlotte    76.0     76.0   76.0       76    76.0
# 3         4          Amelia    34.0     34.0   34.0       34    34.0
# 5         6          Sophia    43.0     43.0   43.0       43    43.0
# 6         7        Isabella    69.0     69.0   69.0       69    69.0
# 7         8             Mia    90.0     90.0   90.0       90    90.0
# 9        10          Harper    76.0     76.0   76.0       76    76.0
# 10       11            Luna    65.0     65.0   65.0       65    65.0
# 13       14       Elizabeth    89.0     89.0   89.0       89    89.0
# 14       15         Eleanor    89.0     89.0   89.0       89    89.0
# 15       16            Ella    56.0     56.0   56.0       56    56.0
# 17       18            Liam    78.0     78.0   78.0       78    78.0
# ...

# %%
df
# Out:
#     Roll No Name_of_Student  Telugu  English  Maths  Science  Social
# 0         1          Olivia    99.0     99.0   99.0       99    99.0
# 1         2            Emma    67.0     67.0   67.0       67    67.0
# 2         3       Charlotte    76.0     76.0   76.0       76    76.0
# 3         4          Amelia    34.0     34.0   34.0       34    34.0
# 4         5             NaN    89.0     89.0   89.0       89    89.0
# 5         6          Sophia    43.0     43.0   43.0       43    43.0
# 6         7        Isabella    69.0     69.0   69.0       69    69.0
# 7         8             Mia    90.0     90.0   90.0       90    90.0
# 8         9          Evelyn    34.0     34.0    NaN       34    34.0
# 9        10          Harper    76.0     76.0   76.0       76    76.0
# 10       11            Luna    65.0     65.0   65.0       65    65.0
# 11       12          Camila    32.0      NaN   32.0       32    32.0
# 12       13          Gianna    78.0     78.0   78.0       78     NaN
# ...

# %%
df.dropna(inplace=True) # this command will perminantly delete the missing values

# %%
df
# Out:
#     Roll No Name_of_Student  Telugu  English  Maths  Science  Social
# 0         1          Olivia    99.0     99.0   99.0       99    99.0
# 1         2            Emma    67.0     67.0   67.0       67    67.0
# 2         3       Charlotte    76.0     76.0   76.0       76    76.0
# 3         4          Amelia    34.0     34.0   34.0       34    34.0
# 5         6          Sophia    43.0     43.0   43.0       43    43.0
# 6         7        Isabella    69.0     69.0   69.0       69    69.0
# 7         8             Mia    90.0     90.0   90.0       90    90.0
# 9        10          Harper    76.0     76.0   76.0       76    76.0
# 10       11            Luna    65.0     65.0   65.0       65    65.0
# 13       14       Elizabeth    89.0     89.0   89.0       89    89.0
# 14       15         Eleanor    89.0     89.0   89.0       89    89.0
# 15       16            Ella    56.0     56.0   56.0       56    56.0
# 17       18            Liam    78.0     78.0   78.0       78    78.0
# ...

# %%
df = pd.read_excel("C:\\Users\\tejas\\OneDrive\\Desktop\\Marks.xlsx",sheet_name="Sheet2")
df
# Out:
#     Roll No Name_of_Student  Telugu  English  Maths  Science  Social
# 0         1          Olivia    99.0     99.0   99.0       99    99.0
# 1         2            Emma    67.0     67.0   67.0       67    67.0
# 2         3       Charlotte    76.0     76.0   76.0       76    76.0
# 3         4          Amelia    34.0     34.0   34.0       34    34.0
# 4         5             NaN    89.0     89.0   89.0       89    89.0
# 5         6          Sophia    43.0     43.0   43.0       43    43.0
# 6         7        Isabella    69.0     69.0   69.0       69    69.0
# 7         8             Mia    90.0     90.0   90.0       90    90.0
# 8         9          Evelyn    34.0     34.0    NaN       34    34.0
# 9        10          Harper    76.0     76.0   76.0       76    76.0
# 10       11            Luna    65.0     65.0   65.0       65    65.0
# 11       12          Camila    32.0      NaN   32.0       32    32.0
# 12       13          Gianna    78.0     78.0   78.0       78     NaN
# ...

# %%
df.fillna("filled") # This command will fill the missing values
# Out:
#     Roll No Name_of_Student  Telugu English   Maths  Science  Social
# 0         1          Olivia    99.0    99.0    99.0       99    99.0
# 1         2            Emma    67.0    67.0    67.0       67    67.0
# 2         3       Charlotte    76.0    76.0    76.0       76    76.0
# 3         4          Amelia    34.0    34.0    34.0       34    34.0
# 4         5          filled    89.0    89.0    89.0       89    89.0
# 5         6          Sophia    43.0    43.0    43.0       43    43.0
# 6         7        Isabella    69.0    69.0    69.0       69    69.0
# 7         8             Mia    90.0    90.0    90.0       90    90.0
# 8         9          Evelyn    34.0    34.0  filled       34    34.0
# 9        10          Harper    76.0    76.0    76.0       76    76.0
# 10       11            Luna    65.0    65.0    65.0       65    65.0
# 11       12          Camila    32.0  filled    32.0       32    32.0
# 12       13          Gianna    78.0    78.0    78.0       78  filled
# ...

# %% [markdown]
# # Data Filtering & Conditional Changes

# %%
df["Total"]=df["Telugu"]+df["English"]+df["Maths"]+df["Science"]+df["Social"]
df["Percentage"]=df["Total"]/500*100
df["Grade"]="pass/fail"
df.dropna(inplace=True)
df
# Out:
#     Roll No Name_of_Student  Telugu  English  Maths  Science  Social  Total  \
# 0         1          Olivia    99.0     99.0   99.0       99    99.0  495.0
# 1         2            Emma    67.0     67.0   67.0       67    67.0  335.0
# 2         3       Charlotte    76.0     76.0   76.0       76    76.0  380.0
# 3         4          Amelia    34.0     34.0   34.0       34    34.0  170.0
# 5         6          Sophia    43.0     43.0   43.0       43    43.0  215.0
# 6         7        Isabella    69.0     69.0   69.0       69    69.0  345.0
# 7         8             Mia    90.0     90.0   90.0       90    90.0  450.0
# 9        10          Harper    76.0     76.0   76.0       76    76.0  380.0
# 10       11            Luna    65.0     65.0   65.0       65    65.0  325.0
# 13       14       Elizabeth    89.0     89.0   89.0       89    89.0  445.0
# 14       15         Eleanor    89.0     89.0   89.0       89    89.0  445.0
# ...

# %%
df.loc[df["Maths"]>85]
# Out:
#     Roll No Name_of_Student  Telugu  English  Maths  Science  Social  Total  \
# 0         1          Olivia    99.0     99.0   99.0       99    99.0  495.0
# 7         8             Mia    90.0     90.0   90.0       90    90.0  450.0
# 13       14       Elizabeth    89.0     89.0   89.0       89    89.0  445.0
# 14       15         Eleanor    89.0     89.0   89.0       89    89.0  445.0
# 18       19            Noah    89.0     89.0   89.0       89    89.0  445.0
# 19       20          Oliver    98.0     98.0   98.0       98    98.0  490.0
#
#     Percentage      Grade
# 0         99.0  pass/fail
# 7         90.0  pass/fail
# 13        89.0  pass/fail
# 14        89.0  pass/fail
# 18        89.0  pass/fail
# 19        98.0  pass/fail

# %%
df.loc[(df["Science"]>80) & (df["Maths"]>80)]
# Out:
#     Roll No Name_of_Student  Telugu  English  Maths  Science  Social  Total  \
# 0         1          Olivia    99.0     99.0   99.0       99    99.0  495.0
# 7         8             Mia    90.0     90.0   90.0       90    90.0  450.0
# 13       14       Elizabeth    89.0     89.0   89.0       89    89.0  445.0
# 14       15         Eleanor    89.0     89.0   89.0       89    89.0  445.0
# 18       19            Noah    89.0     89.0   89.0       89    89.0  445.0
# 19       20          Oliver    98.0     98.0   98.0       98    98.0  490.0
#
#     Percentage      Grade
# 0         99.0  pass/fail
# 7         90.0  pass/fail
# 13        89.0  pass/fail
# 14        89.0  pass/fail
# 18        89.0  pass/fail
# 19        98.0  pass/fail

# %%
df.loc[df["Name_of_Student"].str.contains("n")]
# Out:
#     Roll No Name_of_Student  Telugu  English  Maths  Science  Social  Total  \
# 10       11            Luna    65.0     65.0   65.0       65    65.0  325.0
# 14       15         Eleanor    89.0     89.0   89.0       89    89.0  445.0
#
#     Percentage      Grade
# 10        65.0  pass/fail
# 14        89.0  pass/fail

# %%
df.loc[df["Name_of_Student"].str.startswith("A")]
# Out:
#    Roll No Name_of_Student  Telugu  English  Maths  Science  Social  Total  \
# 3        4          Amelia    34.0     34.0   34.0       34    34.0  170.0
#
#    Percentage      Grade
# 3        34.0  pass/fail

# %%
df.loc[df["Name_of_Student"].str.endswith("h")]
# Out:
#     Roll No Name_of_Student  Telugu  English  Maths  Science  Social  Total  \
# 13       14       Elizabeth    89.0     89.0   89.0       89    89.0  445.0
# 18       19            Noah    89.0     89.0   89.0       89    89.0  445.0
#
#     Percentage      Grade
# 13        89.0  pass/fail
# 18        89.0  pass/fail

# %%
df.loc[df["Percentage"]>80,["Grade"]]="O+"

# %%
df
# Out:
#     Roll No Name_of_Student  Telugu  English  Maths  Science  Social  Total  \
# 0         1          Olivia    99.0     99.0   99.0       99    99.0  495.0
# 1         2            Emma    67.0     67.0   67.0       67    67.0  335.0
# 2         3       Charlotte    76.0     76.0   76.0       76    76.0  380.0
# 3         4          Amelia    34.0     34.0   34.0       34    34.0  170.0
# 5         6          Sophia    43.0     43.0   43.0       43    43.0  215.0
# 6         7        Isabella    69.0     69.0   69.0       69    69.0  345.0
# 7         8             Mia    90.0     90.0   90.0       90    90.0  450.0
# 9        10          Harper    76.0     76.0   76.0       76    76.0  380.0
# 10       11            Luna    65.0     65.0   65.0       65    65.0  325.0
# 13       14       Elizabeth    89.0     89.0   89.0       89    89.0  445.0
# 14       15         Eleanor    89.0     89.0   89.0       89    89.0  445.0
# ...

# %%
df.to_excel("C:\\Users\\tejas\\OneDrive\\Desktop\\Marks.xlsx") # to save the File
